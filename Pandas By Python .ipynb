# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# Creating a Series by passing a list of values, letting pandas create a default integer index:

# %%
s= pd.Series([1,3,5 , np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating a DataFrame by passing a NumPy array, with a datetime index and labeled columns:

# %%
dates =pd.date_range('20200101', periods =30)
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
df =pd.DataFrame(np.random.randn(30,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2020-01-01 -2.001457 -1.374272 -3.223048 -1.637981
# 2020-01-02 -1.768703  0.531682  1.093122  0.287616
# 2020-01-03  1.480325 -0.214404 -1.057091  0.106826
# 2020-01-04  0.798118 -1.058517  0.349866 -0.055175
# 2020-01-05  0.024231  0.286128 -1.055887 -0.015419
# 2020-01-06 -1.713912 -0.124713  0.203384  1.934419
# 2020-01-07  0.463272 -0.474815 -1.859822 -0.744808
# 2020-01-08  0.374144 -1.655230 -0.534951  0.332038
# 2020-01-09  0.610518  0.835317 -1.100115 -0.433393
# 2020-01-10 -1.354864 -1.471497  0.383410 -1.050062
# 2020-01-11  1.258631  0.190341  0.110050  0.723476
# 2020-01-12  1.440355 -1.191420 -0.806524 -0.319007
# 2020-01-13  0.625208 -0.014142 -0.358279  0.079906
# 2020-01-14  2.435358 -1.072250  1.500170 -0.072086
# 2020-01-15 -1.133795  0.697703  0.479783  0.623482
# 2020-01-16  0.677678 -0.213905  0.903670  0.351888
# 2020-01-17  0.393486  0.487946  0.365452  0.962565
# 2020-01-18  0.514922  0.938846  0.914293 -0.612008
# 2020-01-19 -0.978498  1.438695  0.177768 -0.147481
# 2020-01-20 -1.196483  0.083957  0.928956 -0.112760
# 2020-01-21 -1.299530  1.392088  0.958226 -0.672078
# 2020-01-22 -1.205210 -0.648240  0.725273  0.180615
# 2020-01-23 -0.418231 -0.214145  1.577879 -0.409778
# 2020-01-24 -0.714035  0.064110  0.616330  0.516698
# 2020-01-25  0.564532  0.612743 -0.573152  1.268611
# 2020-01-26  0.706312 -0.186314 -0.373714  0.129024
# 2020-01-27 -1.168961 -0.029521  0.110749 -0.390239
# 2020-01-28  1.579792  0.351014 -0.732720  0.256650
# 2020-01-29  0.995443  1.605033  0.503760  1.095731
# 2020-01-30 -0.352253  0.459833  0.195585  0.748704

# %% [markdown]
# Creating a DataFrame by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({'A': 1.,
                        'B': pd.Timestamp('20130102'),
                        'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                        'D': np.array([3] * 4, dtype='int32'),
                        'E': pd.Categorical(["test", "train", "test", "train"]),
                        'F': 'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# The columns of the resulting DataFrame have different dtypes.

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# ---------------------------------

# %% [markdown]
# # Viewing data

# %% [markdown]
# Here is how to view the top and bottom rows of the frame:

# %%
df.head()
# Out:
#                    A         B         C         D
# 2020-01-01 -2.001457 -1.374272 -3.223048 -1.637981
# 2020-01-02 -1.768703  0.531682  1.093122  0.287616
# 2020-01-03  1.480325 -0.214404 -1.057091  0.106826
# 2020-01-04  0.798118 -1.058517  0.349866 -0.055175
# 2020-01-05  0.024231  0.286128 -1.055887 -0.015419

# %%
df.tail(4)
# Out:
#                    A         B         C         D
# 2020-01-27 -1.168961 -0.029521  0.110749 -0.390239
# 2020-01-28  1.579792  0.351014 -0.732720  0.256650
# 2020-01-29  0.995443  1.605033  0.503760  1.095731
# 2020-01-30 -0.352253  0.459833  0.195585  0.748704

# %% [markdown]
# Display the index, columns:

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# describe() shows a quick statistic summary of your data:

# %%
df.describe()
# Out:
#                A          B          C          D
# count  30.000000  30.000000  30.000000  30.000000
# mean   -0.012120   0.001068   0.014081   0.097532
# std     1.168766   0.857581   1.028070   0.724019
# min    -2.001457  -1.655230  -3.223048  -1.637981
# 25%    -1.160170  -0.409712  -0.563601  -0.372431
# 50%     0.383815   0.024984   0.199484   0.093366
# 75%     0.699154   0.520748   0.698037   0.475495
# max     2.435358   1.605033   1.577879   1.934419

# %% [markdown]
# Transposing your data :

# %%
df.T
# Out:
# 2020-01-11  1.258631  0.190341  0.110050  0.723476
# 2020-01-27 -1.168961 -0.029521  0.110749 -0.390239
# 2020-01-19 -0.978498  1.438695  0.177768 -0.147481
# 2020-01-30 -0.352253  0.459833  0.195585  0.748704
# 2020-01-06 -1.713912 -0.124713  0.203384  1.934419
# 2020-01-04  0.798118 -1.058517  0.349866 -0.055175
# 2020-01-17  0.393486  0.487946  0.365452  0.962565
# 2020-01-10 -1.354864 -1.471497  0.383410 -1.050062
# 2020-01-15 -1.133795  0.697703  0.479783  0.623482
# 2020-01-29  0.995443  1.605033  0.503760  1.095731
# 2020-01-24 -0.714035  0.064110  0.616330  0.516698
# 2020-01-22 -1.205210 -0.648240  0.725273  0.180615
# 2020-01-16  0.677678 -0.213905  0.903670  0.351888
# 2020-01-18  0.514922  0.938846  0.914293 -0.612008
# 2020-01-20 -1.196483  0.083957  0.928956 -0.112760
# 2020-01-21 -1.299530  1.392088  0.958226 -0.672078
# 2020-01-02 -1.768703  0.531682  1.093122  0.287616
# 2020-01-14  2.435358 -1.072250  1.500170 -0.072086
# 2020-01-23 -0.418231 -0.214145  1.577879 -0.409778

# %% [markdown]
# -----------------------------------

# %% [markdown]
# # Selection

# %% [markdown]
# --------------------------------

# %% [markdown]
# ## Getting

# %% [markdown]
# Selecting a single column, which yields a Series, equivalent to df.A:

# %%
df['A']
# Out:
# 2020-01-01   -2.001457
# 2020-01-02   -1.768703
# 2020-01-03    1.480325
# 2020-01-04    0.798118
# 2020-01-05    0.024231
# 2020-01-06   -1.713912
# 2020-01-07    0.463272
# 2020-01-08    0.374144
# 2020-01-09    0.610518
# 2020-01-10   -1.354864
# 2020-01-11    1.258631
# 2020-01-12    1.440355
# 2020-01-13    0.625208
# 2020-01-14    2.435358
# 2020-01-15   -1.133795
# 2020-01-16    0.677678
# 2020-01-17    0.393486
# 2020-01-18    0.514922
# 2020-01-19   -0.978498
# 2020-01-20   -1.196483
# 2020-01-21   -1.299530
# 2020-01-22   -1.205210
# 2020-01-23   -0.418231
# 2020-01-24   -0.714035
# 2020-01-25    0.564532
# 2020-01-26    0.706312
# 2020-01-27   -1.168961
# 2020-01-28    1.579792
# 2020-01-29    0.995443
# 2020-01-30   -0.352253
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# Selecting via [], which slices the rows

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2020-01-01 -2.001457 -1.374272 -3.223048 -1.637981
# 2020-01-02 -1.768703  0.531682  1.093122  0.287616
# 2020-01-03  1.480325 -0.214404 -1.057091  0.106826

# %%
df['20200106':'20200107']
# Out:
#                    A         B         C         D
# 2020-01-06 -1.713912 -0.124713  0.203384  1.934419
# 2020-01-07  0.463272 -0.474815 -1.859822 -0.744808

# %% [markdown]
# ## Selection by label

# %% [markdown]
# For getting a cross section using a label :

# %%
df.loc[dates[0]]
# Out:
# A   -2.001457
# B   -1.374272
# C   -3.223048
# D   -1.637981
# Name: 2020-01-01 00:00:00, dtype: float64

# %% [markdown]
# Selecting on a multi-axis by label:

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2020-01-01 -2.001457 -1.374272
# 2020-01-02 -1.768703  0.531682
# 2020-01-03  1.480325 -0.214404
# 2020-01-04  0.798118 -1.058517
# 2020-01-05  0.024231  0.286128
# 2020-01-06 -1.713912 -0.124713
# 2020-01-07  0.463272 -0.474815
# 2020-01-08  0.374144 -1.655230
# 2020-01-09  0.610518  0.835317
# 2020-01-10 -1.354864 -1.471497
# 2020-01-11  1.258631  0.190341
# 2020-01-12  1.440355 -1.191420
# 2020-01-13  0.625208 -0.014142
# 2020-01-14  2.435358 -1.072250
# 2020-01-15 -1.133795  0.697703
# 2020-01-16  0.677678 -0.213905
# 2020-01-17  0.393486  0.487946
# 2020-01-18  0.514922  0.938846
# 2020-01-19 -0.978498  1.438695
# 2020-01-20 -1.196483  0.083957
# 2020-01-21 -1.299530  1.392088
# 2020-01-22 -1.205210 -0.648240
# 2020-01-23 -0.418231 -0.214145
# 2020-01-24 -0.714035  0.064110
# 2020-01-25  0.564532  0.612743
# 2020-01-26  0.706312 -0.186314
# 2020-01-27 -1.168961 -0.029521
# 2020-01-28  1.579792  0.351014
# 2020-01-29  0.995443  1.605033
# 2020-01-30 -0.352253  0.459833

# %% [markdown]
# Showing label slicing, both endpoints are included:

# %%
df.loc['20200102':'20200105',['A','B']]
# Out:
#                    A         B
# 2020-01-02 -1.768703  0.531682
# 2020-01-03  1.480325 -0.214404
# 2020-01-04  0.798118 -1.058517
# 2020-01-05  0.024231  0.286128

# %% [markdown]
# Reduction in the dimensions of the returned object:

# %%
df.loc['20200102',['A','B']]
# Out:
# A   -1.768703
# B    0.531682
# Name: 2020-01-02 00:00:00, dtype: float64

# %% [markdown]
# For getting a scalar value:

# %%
df.loc[dates[0],'A']
# Out:
# -2.0014573496193533

# %% [markdown]
# For getting fast access to a scalar (equivalent to the prior method):

# %%
df.at[dates[0],'A']
# Out:
# -2.0014573496193533

# %% [markdown]
# ## Selection by position

# %% [markdown]
# --------------------

# %% [markdown]
# Select via the position of the passed integers:

# %%
df.iloc[2]
# Out:
# A    1.480325
# B   -0.214404
# C   -1.057091
# D    0.106826
# Name: 2020-01-03 00:00:00, dtype: float64

# %% [markdown]
# By integer slices, acting similar to numpy/python:

# %%
df.iloc[3:5 , 0:2]
# Out:
#                    A         B
# 2020-01-04  0.798118 -1.058517
# 2020-01-05  0.024231  0.286128

# %% [markdown]
# By lists of integer position locations, similar to the numpy/python style:

# %%
df.iloc[[1,2,4], [0,2]]
# Out:
#                    A         C
# 2020-01-02 -1.768703  1.093122
# 2020-01-03  1.480325 -1.057091
# 2020-01-05  0.024231 -1.055887

# %% [markdown]
# For slicing rows explicitly:

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2020-01-01 -1.374272 -3.223048
# 2020-01-02  0.531682  1.093122
# 2020-01-03 -0.214404 -1.057091
# 2020-01-04 -1.058517  0.349866
# 2020-01-05  0.286128 -1.055887
# 2020-01-06 -0.124713  0.203384
# 2020-01-07 -0.474815 -1.859822
# 2020-01-08 -1.655230 -0.534951
# 2020-01-09  0.835317 -1.100115
# 2020-01-10 -1.471497  0.383410
# 2020-01-11  0.190341  0.110050
# 2020-01-12 -1.191420 -0.806524
# 2020-01-13 -0.014142 -0.358279
# 2020-01-14 -1.072250  1.500170
# 2020-01-15  0.697703  0.479783
# 2020-01-16 -0.213905  0.903670
# 2020-01-17  0.487946  0.365452
# 2020-01-18  0.938846  0.914293
# 2020-01-19  1.438695  0.177768
# 2020-01-20  0.083957  0.928956
# 2020-01-21  1.392088  0.958226
# 2020-01-22 -0.648240  0.725273
# 2020-01-23 -0.214145  1.577879
# 2020-01-24  0.064110  0.616330
# 2020-01-25  0.612743 -0.573152
# 2020-01-26 -0.186314 -0.373714
# 2020-01-27 -0.029521  0.110749
# 2020-01-28  0.351014 -0.732720
# 2020-01-29  1.605033  0.503760
# 2020-01-30  0.459833  0.195585

# %% [markdown]
# for getting a value explicitly:

# %%
df.iloc[1,1]
# Out:
# 0.5316820330583498

# %% [markdown]
# -----------------------------

# %% [markdown]
# ## Boolean indexing

# %% [markdown]
# Using a single column's values to select data

# %%
df[df['A']>0]
# Out:
#                    A         B         C         D
# 2020-01-03  1.480325 -0.214404 -1.057091  0.106826
# 2020-01-04  0.798118 -1.058517  0.349866 -0.055175
# 2020-01-05  0.024231  0.286128 -1.055887 -0.015419
# 2020-01-07  0.463272 -0.474815 -1.859822 -0.744808
# 2020-01-08  0.374144 -1.655230 -0.534951  0.332038
# 2020-01-09  0.610518  0.835317 -1.100115 -0.433393
# 2020-01-11  1.258631  0.190341  0.110050  0.723476
# 2020-01-12  1.440355 -1.191420 -0.806524 -0.319007
# 2020-01-13  0.625208 -0.014142 -0.358279  0.079906
# 2020-01-14  2.435358 -1.072250  1.500170 -0.072086
# 2020-01-16  0.677678 -0.213905  0.903670  0.351888
# 2020-01-17  0.393486  0.487946  0.365452  0.962565
# 2020-01-18  0.514922  0.938846  0.914293 -0.612008
# 2020-01-25  0.564532  0.612743 -0.573152  1.268611
# 2020-01-26  0.706312 -0.186314 -0.373714  0.129024
# 2020-01-28  1.579792  0.351014 -0.732720  0.256650
# 2020-01-29  0.995443  1.605033  0.503760  1.095731

# %% [markdown]
# Selecting values from a DataFrame where a boolean condition is met

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2020-01-01       NaN       NaN       NaN       NaN
# 2020-01-02       NaN  0.531682  1.093122  0.287616
# 2020-01-03  1.480325       NaN       NaN  0.106826
# 2020-01-04  0.798118       NaN  0.349866       NaN
# 2020-01-05  0.024231  0.286128       NaN       NaN
# 2020-01-06       NaN       NaN  0.203384  1.934419
# 2020-01-07  0.463272       NaN       NaN       NaN
# 2020-01-08  0.374144       NaN       NaN  0.332038
# 2020-01-09  0.610518  0.835317       NaN       NaN
# 2020-01-10       NaN       NaN  0.383410       NaN
# 2020-01-11  1.258631  0.190341  0.110050  0.723476
# 2020-01-12  1.440355       NaN       NaN       NaN
# 2020-01-13  0.625208       NaN       NaN  0.079906
# 2020-01-14  2.435358       NaN  1.500170       NaN
# 2020-01-15       NaN  0.697703  0.479783  0.623482
# 2020-01-16  0.677678       NaN  0.903670  0.351888
# 2020-01-17  0.393486  0.487946  0.365452  0.962565
# 2020-01-18  0.514922  0.938846  0.914293       NaN
# 2020-01-19       NaN  1.438695  0.177768       NaN
# 2020-01-20       NaN  0.083957  0.928956       NaN
# 2020-01-21       NaN  1.392088  0.958226       NaN
# 2020-01-22       NaN       NaN  0.725273  0.180615
# 2020-01-23       NaN       NaN  1.577879       NaN
# 2020-01-24       NaN  0.064110  0.616330  0.516698
# 2020-01-25  0.564532  0.612743       NaN  1.268611
# 2020-01-26  0.706312       NaN       NaN  0.129024
# 2020-01-27       NaN       NaN  0.110749       NaN
# 2020-01-28  1.579792  0.351014       NaN  0.256650
# 2020-01-29  0.995443  1.605033  0.503760  1.095731
# 2020-01-30       NaN  0.459833  0.195585  0.748704

# %% [markdown]
# ----------------

# %% [markdown]
# ## Setting

# %% [markdown]
# Setting a new column automatically aligns the data by the indexes

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %% [markdown]
# setting values by label :

# %%
df.at[dates[0], 'A']=0
df
# Out:
#                    A         B         C         D
# 2020-01-01  0.000000 -1.374272 -3.223048 -1.637981
# 2020-01-02 -1.768703  0.531682  1.093122  0.287616
# 2020-01-03  1.480325 -0.214404 -1.057091  0.106826
# 2020-01-04  0.798118 -1.058517  0.349866 -0.055175
# 2020-01-05  0.024231  0.286128 -1.055887 -0.015
# 2020-01-20 -1.196483  0.083957  0.928956  5
# 2020-01-21 -1.299530  1.392088  0.958226  5
# 2020-01-22 -1.205210 -0.648240  0.725273  5
# 2020-01-23 -0.418231 -0.214145  1.577879  5
# 2020-01-24 -0.714035  0.064110  0.616330  5
# 2020-01-25  0.564532  0.612743 -0.573152  5
# 2020-01-26  0.706312 -0.186314 -0.373714  5
# 2020-01-27 -1.168961 -0.029521  0.110749  5
# 2020-01-28  1.579792  0.351014 -0.732720  5
# 2020-01-29  0.995443  1.605033  0.503760  5
# 2020-01-30 -0.352253  0.459833  0.195585  5

# %% [markdown]
# -----------------------------

# %% [markdown]
# ## Missing Data

# %% [markdown]
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data.

# %%
df1= df.reindex(index= dates[0:4],columns = list(df.columns)+['E'])

# %%
df1.loc[dates[0]:dates[1], 'E'] = 1

# %%
df1
# Out:
#                    A         B         C  D    E
# 2020-01-01  0.000000  0.000000 -3.223048  5  1.0
# 2020-01-02 -1.768703  0.531682  1.093122  5  1.0
# 2020-01-03  1.480325 -0.214404 -1.057091  5  NaN
# 2020-01-04  0.798118 -1.058517  0.349866  5  NaN

# %% [markdown]
# To drop any rows that have missing data

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D    E
# 2020-01-01  0.000000  0.000000 -3.223048  5  1.0
# 2020-01-02 -1.768703  0.531682  1.093122  5  1.0

# %% [markdown]
# Filling missing data

# %%
df1.fillna(value=6)
# Out:
#                    A         B         C  D    E
# 2020-01-01  0.000000  0.000000 -3.223048  5  1.0
# 2020-01-02 -1.768703  0.531682  1.093122  5  1.0
# 2020-01-03  1.480325 -0.214404 -1.057091  5  6.0
# 2020-01-04  0.798118 -1.058517  0.349866  5  6.0

# %% [markdown]
# To get the boolean mask where values are nan

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E
# 2020-01-01  False  False  False  False  False
# 2020-01-02  False  False  False  False  False
# 2020-01-03  False  False  False  False   True
# 2020-01-04  False  False  False  False   True

# %% [markdown]
# ------------------------

# %% [markdown]
# ## Operations

# %% [markdown]
# Performing a descriptive statistic:

# %%
df.mean()
# Out:
# A    0.054595
# B    0.046877
# C    0.014081
# D    5.000000
# dtype: float64

# %% [markdown]
# Same operations on the other axis:

# %%
df.mean(1)
# Out:
# 2020-01-01    0.444238
# 2020-01-02    1.214025
# 2020-01-03    1.302208
# 2020-01-04    1.272367
# 2020-01-05    1.063618
# 2020-01-06    0.841190
# 2020-01-07    0.782159
# 2020-01-08    0.795991
# 2020-01-09    1.336430
# 2020-01-10    0.639263
# 2020-01-11    1.639756
# 2020-01-12    1.110603
# 2020-01-13    1.313197
# 2020-01-14    1.965820
# 2020-01-15    1.260923
# 2020-01-16    1.591861
# 2020-01-17    1.561721
# 2020-01-18    1.842016
# 2020-01-19    1.409491
# 2020-01-20    1.204108
# 2020-01-21    1.512696
# 2020-01-22    0.967956
# 2020-01-23    1.486376
# 2020-01-24    1.241601
# 2020-01-25    1.401031
# 2020-01-26    1.286571
# 2020-01-27    0.978066
# 2020-01-28    1.549522
# 2020-01-29    2.026059
# 2020-01-30    1.325791
# Freq: D, dtype: float64

# %% [markdown]
# ### Apply

# %% [markdown]
# Applying functions to the data :

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C    D
# 2020-01-01  0.000000  0.000000 -3.223048    5
# 2020-01-02 -1.768703  0.531682 -2.129926   10
# 2020-01-03 -0.288378  0.317278 -3.187017   15
# 2020-01-04  0.509740 -0.741239 -2.837151   20
# 2020-01-05  0.533971 -0.455112 -3.893037   25
# 2020-01-06 -1.179941 -0.579825 -3.689653   30
# 2020-01-07 -0.716669 -1.054640 -5.549476   35
# 2020-01-08 -0.342526 -2.709870 -6.084427   40
# 2020-01-09  0.267992 -1.874553 -7.184542   45
# 2020-01-10 -1.086871 -3.346050 -6.801131   50
# 2020-01-11  0.171760 -3.155708 -6.691081   55
# 2020-01-12  1.612115 -4.347128 -7.497606   60
# 2020-01-13  2.237323 -4.361270 -7.855884   65
# 2020-01-14  4.672682 -5.433520 -6.355714   70
# 2020-01-15  3.538887 -4.735817 -5.875931   75
# 2020-01-16  4.216565 -4.949722 -4.972261   80
# 2020-01-17  4.610050 -4.461776 -4.606809   85
# 2020-01-18  5.124973 -3.522930 -3.692515   90
# 2020-01-19  4.146475 -2.084234 -3.514747   95
# 2020-01-20  2.949992 -2.000277 -2.585791  100
# 2020-01-21  1.650462 -0.608189 -1.627565  105
# 2020-01-22  0.445252 -1.256430 -0.902292  110
# 2020-01-23  0.027021 -1.470575  0.675587  115
# 2020-01-24 -0.687014 -1.406465  1.291918  120
# 2020-01-25 -0.122482 -0.793723  0.718766  125
# 2020-01-26  0.583830 -0.980036  0.345052  130
# 2020-01-27 -0.585131 -1.009558  0.455801  135
# 2020-01-28  0.994661 -0.658544 -0.276919  140
# 2020-01-29  1.990104  0.946490  0.226841  145
# 2020-01-30  1.637851  1.406323  0.422426  150

# %%
df.apply(lambda x: x.max()- x.min())
# Out:
# A    4.204061
# B    3.260264
# C    4.800927
# D    0.000000
# dtype: float64

# %% [markdown]
# ### Histogramming

# %%
s= pd.Series(np.random.randint(0,7,size=10))
s
# Out:
# 0    1
# 1    1
# 2    6
# 3    5
# 4    4
# 5    4
# 6    5
# 7    2
# 8    6
# 9    6
# dtype: int64

# %%
s.value_counts()
# Out:
# 6    3
# 5    2
# 4    2
# 1    2
# 2    1
# dtype: int64

# %% [markdown]
# ### String methods

# %% [markdown]
# Series is equipped with a set of string processing methods in the str attribute that make it easy to operate on each element of the array

# %%
 s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ----------------------

# %% [markdown]
# ## Merge

# %% [markdown]
# ### Concat

# %% [markdown]
# pandas provides various facilities for easily combining together Series and DataFrame objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations

# %% [markdown]
# Concatenating pandas objects together with concat():

# %%
df =pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0 -0.821641  0.453859 -1.512757 -0.965526
# 1 -0.106935  0.798325  1.411346 -0.312907
# 2  1.157679  1.302998 -0.017945  0.699753
# 3  0.337376 -1.222624 -0.258270 -0.404400
# 4  0.791831  1.387894 -1.285076 -0.327651
# 5  0.729569 -2.341574  0.993737 -1.443218
# 6 -0.365446 -0.441710  0.425470 -1.197222
# 7 -0.169398  1.675942  0.367850 -0.755665
# 8 -1.285796  0.913650  0.537736 -0.375088
# 9 -2.401779  0.049719  0.414795 -0.469965

# %%
pieces = [df[:3], df[3:7] , df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.821641  0.453859 -1.512757 -0.965526
# 1 -0.106935  0.798325  1.411346 -0.312907
# 2  1.157679  1.302998 -0.017945  0.699753
# 3  0.337376 -1.222624 -0.258270 -0.404400
# 4  0.791831  1.387894 -1.285076 -0.327651
# 5  0.729569 -2.341574  0.993737 -1.443218
# 6 -0.365446 -0.441710  0.425470 -1.197222
# 7 -0.169398  1.675942  0.367850 -0.755665
# 8 -1.285796  0.913650  0.537736 -0.375088
# 9 -2.401779  0.049719  0.414795 -0.469965

# %% [markdown]
# ---------------------------

# %% [markdown]
# ### Join

# %% [markdown]
# sql style merges

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left,right , on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# ## Grouping

# %% [markdown]
# By “group by” we are referring to a process involving one or more of the following steps:
#
# *Splitting the data into groups based on some criteria
#
# *Applying a function to each group independently
#
# *Combining the results into a data structure

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                             'foo', 'bar', 'foo', 'foo'],
                      'B': ['one', 'one', 'two', 'three',
                             'two', 'two', 'one', 'three'],
                       'C': np.random.randn(8),
                       'D': np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -0.132518  1.237085
# 1  bar    one  0.267716  0.786426
# 2  foo    two  0.513740 -0.870485
# 3  bar  three -0.730800 -0.932058
# 4  foo    two -1.826577  0.122173
# 5  bar    two  0.259714 -0.968665
# 6  foo    one -0.644825 -0.276614
# 7  foo  three  1.833351 -0.678733

# %% [markdown]
# Grouping and then applying the sum() function to the resulting groups

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -0.203370 -1.114297
# foo -0.256828 -0.466574

# %% [markdown]
# Grouping by multiple columns forms a hierarchical index, and again we can apply the sum() function

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.267716  0.786426
#     three -0.730800 -0.932058
#     two    0.259714 -0.968665
# foo one   -0.777342  0.960471
#     three  1.833351 -0.678733
#     two   -1.312837 -0.748312

# %% [markdown]
# ## Reshaping

# %% [markdown]
# ### Stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                         'foo', 'foo', 'qux', 'qux'],
                        ['one', 'two', 'one', 'two',
                         'one', 'two', 'one', 'two']]))

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

# %%
df2=df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -0.670220 -1.223240
#       two     1.743816 -1.902787
# baz   one     0.076969  0.095575
#       two     1.880124  0.004499

# %% [markdown]
# The stack() method “compresses” a level in the DataFrame’s columns

# %%
stacked=df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.670220
#                B   -1.223240
#        two     A    1.743816
#                B   -1.902787
# baz    one     A    0.076969
#                B    0.095575
#        two     A    1.880124
#                B    0.004499
# dtype: float64

# %% [markdown]
# With a “stacked” DataFrame or Series (having a MultiIndex as the index), the inverse operation of stack() is unstack(), which by default unstacks the last level:

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.670220 -1.223240
#       two     1.743816 -1.902787
# baz   one     0.076969  0.095575
#       two     1.880124  0.004499

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.670220  1.743816
#       B -1.223240 -1.902787
# baz   A  0.076969  1.880124
#       B  0.095575  0.004499

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.670220  0.076969
#        B -1.223240  0.095575
# two    A  1.743816  1.880124
#        B -1.902787  0.004499

# %% [markdown]
# ---------------------------

# %% [markdown]
# ## Time series

# %% [markdown]
# pandas has simple, powerful, and efficient functionality for performing resampling operations during frequency conversion (e.g., converting secondly data into 5-minutely data). This is extremely common in, but not limited to, financial applications

# %%
rng = pd.date_range('1/1/2019', periods=100, freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample('5Min').sum()
# Out:
# 2019-01-01    26300
# Freq: 5T, dtype: int64

# %% [markdown]
# Time zone representation:

# %%
 rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06   -0.208179
# 2012-03-07    0.581675
# 2012-03-08   -0.577426
# 2012-03-09    1.101941
# 2012-03-10    0.009417
# Freq: D, dtype: float64

# %%
ts_utc=ts.tz_localize('UTC')
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.208179
# 2012-03-07 00:00:00+00:00    0.581675
# 2012-03-08 00:00:00+00:00   -0.577426
# 2012-03-09 00:00:00+00:00    1.101941
# 2012-03-10 00:00:00+00:00    0.009417
# Freq: D, dtype: float64

# %% [markdown]
# Converting to another time zone:

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00   -0.208179
# 2012-03-06 19:00:00-05:00    0.581675
# 2012-03-07 19:00:00-05:00   -0.577426
# 2012-03-08 19:00:00-05:00    1.101941
# 2012-03-09 19:00:00-05:00    0.009417
# Freq: D, dtype: float64

# %% [markdown]
# Converting between period and timestamp enables some convenient arithmetic functions to be used. In the following example, we convert a quarterly frequency with year ending in November to 9am of the end of the month following the quarter end:

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)

# %%
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

# %%
ts.head()
# Out:
# 1990-03-01 09:00    0.011655
# 1990-06-01 09:00   -0.553008
# 1990-09-01 09:00   -0.588911
# 1990-12-01 09:00   -1.185580
# 1991-03-01 09:00    0.864670
# Freq: H, dtype: float64

# %% [markdown]
# ---------------------------

# %% [markdown]
# ## Categoricals

# %% [markdown]
# pandas can include categorical data in a DataFrame

# %%
df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],
                       "raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})

# %% [markdown]
# Convert the raw grades to a categorical data type

# %%
df["grade"]=df['raw_grade'].astype('category')
df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %% [markdown]
# Rename the categories to more meaningful names (assigning to Series.cat.categories() is in place!)

# %%
df['grade'].cat.categories = ["very good" , "good" , "very bad"]

# %% [markdown]
# Reorder the categories and simultaneously add the missing categories (methods under Series.cat() return a new Series by default)

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium",
                                                  "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %% [markdown]
# Sorting is per order in the categories, not lexical order

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %% [markdown]
# Grouping by a categorical column also shows empty categories

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ## Plotting

# %% [markdown]
# We use the standard convention for referencing the matplotlib API:

# %%
import matplotlib.pyplot as plt
plt.close('all')

# %%
ts = pd.Series(np.random.randn(1000),
index=pd.date_range('1/1/2000', periods=1000))
ts=ts.cumsum()
ts.plot()

# %% [markdown]
# -----------------------------

# %% [markdown]
# ### DataCheat for pandas

# %%
class PDF(object):
  def __init__(self, pdf, size=(200,200)):
    self.pdf = pdf
    self.size = size

  def _repr_html_(self):
    return '<iframe src={0} width={1[0]} height={1[1]}></iframe>'.format(self.pdf, self.size)

  def _repr_latex_(self):
    return r'\includegraphics[width=1.0\textwidth]{{{0}}}'.format(self.pdf)

# %%
PDF('Pandas_Cheat_Sheet.pdf',size=(900,700))
# Out:
# \includegraphics[width=1.0\textwidth]{Pandas_Cheat_Sheet.pdf}
